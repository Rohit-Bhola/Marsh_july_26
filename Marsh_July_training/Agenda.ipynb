-- %%
Zorder and liquid


Types of Views 


DAB

Lakehouse federation
Open Sharing
Databricks SQL 
UC table to Power bi

Spark ( DAG )
Optimization on Spark 


Free edition 
 

--Unity Catalog
--GitHub
--CLI
--Pipelines
--Certification 
--mid and post assessment
