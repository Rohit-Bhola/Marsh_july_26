-- %%
%sql
-- UDF: Classify transaction amount into value tiers

create or replace function dev.naval.classify_amount_tier(amount double)
returns string
return
  case
    when amount < 5000  then 'Low'
    when amount < 20000 then 'Medium'
    when amount < 40000 then 'High'
    else                     'Very High'
  end
