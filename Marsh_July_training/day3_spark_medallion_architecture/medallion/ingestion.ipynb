# %%
# %run "/Workspace/Users/tlyemul@gmail.com/Marsh_July_training/day3_spark_medallion_architecture/medallion/includes"

# %%
dbutils.widgets.text("catalog","default")
catalog=dbutils.widgets.get("catalog")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df=spark.read.csv(f"/Volumes/{catalog}/naval/raw/transactions.csv",header=True,inferSchema=True)

df_with_metadata=add_metadata_col(df)

df_with_metadata.write.mode("overwrite").saveAsTable(f"{catalog}.naval_bronze.transactions")
